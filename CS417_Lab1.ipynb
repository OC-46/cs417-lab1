# %% [markdown]
# <a href="https://colab.research.google.com/github/OC-46/cs417-lab1/blob/main/CS417_Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CS 417 - Lab 1: Google Colab Introduction
# **Date:** 1/20/2026
# This notebook demonstrates basic Python concepts including:
# - Print statements
# - Variables
# - Basic arithmetic operations
# - String formatting

# %%
# Basic print statements
print("Welcome to Google Colab!")
print("Python makes programming fun!")
# Out:
# Welcome to Google Colab!
# Python makes programming fun!

# %%
# Working with variables
favorite_food = "steak"
favorite_number = 4
favorite_color = "blue"
print("My favorite food is:", favorite_food)
print("My favorite number is:", favorite_number)
print("My favorite color is:", favorite_color)
# Out:
# My favorite food is: steak
# My favorite number is: 4
# My favorite color is: blue

# %%
v1 = 6
v2 = 7
add = v1 + v2
print(f"when you add {v1} and {v2} you get {add}")
# Out:
# when you add 6 and 7 you get 13
